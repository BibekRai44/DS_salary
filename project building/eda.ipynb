# %% [markdown]
# # Performing Data EDA

# %%
#importing necessary libraries

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#reading dataset

df=pd.read_csv('Cleaned_data.csv')

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly_salary', 'employer_provided_salary', 'min_salary', 'max_salary',
#        'avg_salary', 'company_txt', 'state', 'job_state', 'age', 'python', 'R',
#        'spark', 'aws', 'excel'],
#       dtype='object')

# %%
df.shape
# Out:
# (742, 28)

# %%
df.describe()
# Out:
#            Rating      Founded  hourly_salary  employer_provided_salary  \
# count  742.000000   742.000000     742.000000                742.000000
# mean     3.618868  1837.154987       0.032345                  0.022911
# std      0.801210   497.183763       0.177034                  0.149721
# min     -1.000000    -1.000000       0.000000                  0.000000
# 25%      3.300000  1939.000000       0.000000                  0.000000
# 50%      3.700000  1988.000000       0.000000                  0.000000
# 75%      4.000000  2007.000000       0.000000                  0.000000
# max      5.000000  2019.000000       1.000000                  1.000000
#
#        min_salary  max_salary  avg_salary       state         age      python  \
# count  725.000000  742.000000  725.000000  742.000000  742.000000  742.000000
# mean    73.267586  127.183288  100.172414    0.557951   49.389488    0.528302
# std     30.869984   46.909006   38.264093    0.496965   53.962906    0.499535
# ...

# %%
df.dtypes
# Out:
# Job Title                    object
# Salary Estimate              object
# Job Description              object
# Rating                      float64
# Company Name                 object
# Location                     object
# Headquarters                 object
# Size                         object
# Founded                       int64
# Type of ownership            object
# Industry                     object
# Sector                       object
# Revenue                      object
# Competitors                  object
# hourly_salary                 int64
# employer_provided_salary      int64
# min_salary                  float64
# max_salary                    int64
# avg_salary                  float64
# company_txt                  object
# state                         int64
# job_state                    object
# age                           int64
# python                        int64
# R                             int64
# spark                         int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Job Title                 742 non-null    object
#  1   Salary Estimate           742 non-null    object
#  2   Job Description           742 non-null    object
#  3   Rating                    742 non-null    float64
#  4   Company Name              742 non-null    object
#  5   Location                  742 non-null    object
#  6   Headquarters              742 non-null    object
#  7   Size                      742 non-null    object
#  8   Founded                   742 non-null    int64
#  9   Type of ownership         742 non-null    object
#  10  Industry                  742 non-null    object
#  11  Sector                    742 non-null    object
#  12  Revenue                   742 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Job Title                    0
# Salary Estimate              0
# Job Description              0
# Rating                       0
# Company Name                 0
# Location                     0
# Headquarters                 0
# Size                         0
# Founded                      0
# Type of ownership            0
# Industry                     0
# Sector                       0
# Revenue                      0
# Competitors                  0
# hourly_salary                0
# employer_provided_salary     0
# min_salary                  17
# max_salary                   0
# avg_salary                  17
# company_txt                  0
# state                        0
# job_state                    0
# age                          0
# python                       0
# R                            0
# spark                        0
# aws                          0
# excel                        0
# dtype: int64

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'
		
## Job title and seniority 
		
##  Fix state Los Angeles 

##  Job description length 

##  Competitor count

## hourly wage to annual 

#remove new line from job title

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)
df['job_simp'].value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df['seniority'].value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
#fixing job state(los angeles)

df['job_state']=df['job_state'].apply(lambda x:x.strip() if x.strip().lower() != 'los angeles' else 'CA')

# %%
df['job_state'].value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# NC     21
# WA     21
# NJ     17
# FL     16
# OH     14
# TN     13
# DC     11
# CO     11
# WI     10
# UT     10
# IN     10
# AZ      9
# MO      9
# AL      8
# GA      6
# DE      6
# KY      6
# MI      6
# CT      5
# IA      5
# LA      4
# OR      4
# NE      4
# NM      3
# KS      3
# ID      2
# MN      2
# RI      1
# SC      1
# Name: job_state, dtype: int64

# %%
#job description length

df['job_desc_length']=df['Job Description'].apply(lambda x:len(x))
df['job_desc_length']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: job_desc_length, Length: 742, dtype: int64

# %%
#competitor count

df['num_comp']=df['Competitors'].apply(lambda x:len(x.split(',')) if x!='-1' else 0)

# %%
df['num_comp']
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: num_comp, Length: 742, dtype: int64

# %%
df['Competitors']
# Out:
# 0                                                     -1
# 1                                                     -1
# 2                                                     -1
# 3      Oak Ridge National Laboratory, National Renewa...
# 4                   Commerce Signals, Cardlytics, Yodlee
#                              ...
# 737                           Pfizer, AstraZeneca, Merck
# 738                      See Tickets, TicketWeb, Vendini
# 739                                                   -1
# 740                                                   -1
# 741                                                   -1
# Name: Competitors, Length: 742, dtype: object

# %%
#hourly wage to annual

df['min_salary']=df.apply(lambda x:x.min_salary*2 if x.hourly_salary==1 else x.min_salary ,axis=1)
df['max_salary']=df.apply(lambda x:x.max_salary*2 if x.hourly_salary==1 else x.max_salary ,axis=1)

# %%
df[df.hourly_salary ==1][['hourly_salary','min_salary','max_salary']]
# Out:
#      hourly_salary  min_salary  max_salary
# 165              1        34.0          48
# 177              1        42.0          68
# 197              1        36.0          50
# 202              1        42.0          68
# 210              1        30.0          50
# 246              1        34.0          48
# 271              1        42.0          68
# 337              1        36.0          50
# 345              1        48.0          78
# 357              1        42.0          68
# 363              1         NaN          56
# 408              1        42.0          58
# 409              1        20.0          34
# 492              1        36.0          50
# 509              1        48.0          78
# 533              1        42.0          68
# 542              1         NaN          56
# 617              1        42.0          58
# 618              1        20.0          34
# 645              1        54.0          94
# 666              1        36.0          50
# ...

# %%
df.head(1)
# Out:
#         Job Title             Salary Estimate  \
# 0  Data Scientist  $53K-$91K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
#
#              Company Name         Location Headquarters  \
# 0  Tecolote Research\n3.8  Albuquerque, NM   Goleta, CA
#
#                     Size  Founded  Type of ownership  ... age python  R spark  \
# 0  501 to 1000 employees     1973  Company - Private  ...  50      1  0     0
#
#    aws  excel        job_simp  seniority  job_desc_length num_comp
# 0    0      1  data scientist         na             2536        0
#
# [1 rows x 32 columns]

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\n', ''))
df['company_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_txt, Length: 742, dtype: object

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# 740                               Data Science Manager
# 741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# ...

# %%
for i in df.columns[1:]:  
    if (df[i].dtype == 'object') or (df[i].dtype == 'int64'):
            sns.countplot(data = df, y = i,color='grey')
            plt.title(' {} count'.format(i))
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/tensorflow-test/env/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/tensorflow-test/env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# ...

# %%
df['Rating'].hist()
# Out:
# <AxesSubplot: >

# %%
df['age'].hist()
# Out:
# <AxesSubplot: >

# %%
df['job_desc_length'].hist()
# Out:
# <AxesSubplot: >

# %%
df.dtypes
# Out:
# Job Title                    object
# Salary Estimate              object
# Job Description              object
# Rating                      float64
# Company Name                 object
# Location                     object
# Headquarters                 object
# Size                         object
# Founded                       int64
# Type of ownership            object
# Industry                     object
# Sector                       object
# Revenue                      object
# Competitors                  object
# hourly_salary                 int64
# employer_provided_salary      int64
# min_salary                   object
# max_salary                   object
# company_txt                  object
# state                         int64
# job_state                    object
# age                           int64
# python                        int64
# R                             int64
# spark                         int64
# aws                           int64
# ...

# %%
df.boxplot(column=['age','avg_salary','Rating','hourly_salary'])
# Out:
# <AxesSubplot: >

# %%
df[['age','Rating','job_desc_length']].corr()
# Out:
#                       age    Rating  job_desc_length
# age              1.000000  0.026164         0.164730
# Rating           0.026164  1.000000        -0.012281
# job_desc_length  0.164730 -0.012281         1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','avg_salary','hourly_salary','Rating','job_desc_length','num_comp']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot: >

# %%
sns.barplot(data=df,x=df['age'].head(10),y=df['Rating'].head(10),color='grey')
plt.title("Company age and their rating",color="DarkBlue")
plt.xlabel("Company age")
plt.ylabel("Company Rating")
# Out:
# Text(0, 0.5, 'Company Rating')

# %%
df.to_csv("data_after_eda.csv",index=True)
