# %% [markdown]
# ### What we want to do here
#
# **Salary Parsing**
#
# **Company name only**
#
# **state field**
#
# **age of company**
#
# **parsing of job description(Python etc)**

# %%
#importing necessary libraries

import pandas as pd

# %%
#reading csv
df=pd.read_csv('/Users/bibekrai/workspace/DS_salary/glassdoor_jobs.csv')

# %% [markdown]
# # Salary Parsing

# %%
df=df[df['Salary Estimate']!='-1']

# %%
df=df.drop(columns='Unnamed: 0')

# %%
df['hourly_salary']=df['Salary Estimate'].apply(lambda x:1 if 'per hour' in x.lower() else 0 )

# %%
df['employer_provided_salary']=df['Salary Estimate'].apply(lambda x:1 if 'employer provided salary' in x.lower() else 0 )

# %%
salary=df['Salary Estimate'].apply(lambda x:x.split('(')[0])

# %%
salary.head()
# Out:
# 0     $53K-$91K
# 1    $63K-$112K
# 2     $80K-$90K
# 3     $56K-$97K
# 4    $86K-$143K
# Name: Salary Estimate, dtype: object

# %%
min_KD=salary.apply(lambda x:x.replace('$','').replace('K','').replace('Per Hour',''))

# %%
min_KD.head()
# Out:
# 0     53-91
# 1    63-112
# 2     80-90
# 3     56-97
# 4    86-143
# Name: Salary Estimate, dtype: object

# %%
min_hr=df['Salary Estimate'].apply(lambda x:x.lower().replace('per hour','').replace('employer salary provided',''))

# %%
df['min_salary'] = min_KD.apply(lambda x: int(x.split('-')[0]) if x.split('-')[0].isdigit() else None)

# %%
df['max_salary'] = min_KD.apply(lambda x: int(x.split('-')[1]) if x.split('-')[1].isdigit() else int(x.split('-')[1]))

# %%
df['min_salary']
# Out:
# 0      53.0
# 1      63.0
# 2      80.0
# 3      56.0
# 4      86.0
#        ...
# 950    58.0
# 951    72.0
# 952    56.0
# 953    95.0
# 955    61.0
# Name: min_salary, Length: 742, dtype: float64

# %%
df['max_salary']
# Out:
# 0       91
# 1      112
# 2       90
# 3       97
# 4      143
#       ...
# 950    111
# 951    133
# 952     91
# 953    160
# 955    126
# Name: max_salary, Length: 742, dtype: int64

# %%
df.dtypes
# Out:
# Job Title                    object
# Salary Estimate              object
# Job Description              object
# Rating                      float64
# Company Name                 object
# Location                     object
# Headquarters                 object
# Size                         object
# Founded                       int64
# Type of ownership            object
# Industry                     object
# Sector                       object
# Revenue                      object
# Competitors                  object
# hourly_salary                 int64
# employer_provided_salary      int64
# min_salary                  float64
# max_salary                    int64
# dtype: object

# %%
df['avg_salary']=(df.min_salary+df.max_salary)/2

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %% [markdown]
# # Company Name Extraction

# %%
df['company_txt']=df.apply(lambda x:x['Company Name'] if x['Rating']<0 else x['Company Name'][:-3],axis=1)

# %% [markdown]
# # Same state or not

# %%
df['state']=df.apply(lambda x:1 if x['Location']==x['Headquarters'] else 0,axis=1)

# %%
df['job_state']=df['Location'].apply(lambda x:x.split(',')[1])

# %% [markdown]
# # age of company

# %%
df['age']=df['Founded'].apply(lambda x:x if x<1 else 2023-x)

# %% [markdown]
# # parsing of job description

# %%
#python

df['python']=df['Job Description'].apply(lambda x:1 if 'python' in x.lower() else 0)

# %%
# R Language

df['R']=df['Job Description'].apply(lambda x:1 if 'r studio' in x.lower() else 0)

# %%
# spark

df['spark']=df['Job Description'].apply(lambda x:1 if 'spark' in x.lower() else 0)

# %%
# aws

df['aws']=df['Job Description'].apply(lambda x:1 if 'aws' in x.lower() else 0)

# %%
# excel 

df['excel']=df['Job Description'].apply(lambda x:1 if 'excel' in x.lower() else 0)

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
df.to_csv('Cleaned_data.csv',index=True)
